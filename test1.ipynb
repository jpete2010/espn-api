# %%
from espn_api.football import League

# %%
league = League(league_id=753911, year=2025, espn_s2='AECSbKZxmko3IVdPdkTGtFd9GbPnjt8tsnNWCdt1F4%2FcDNjVw%2FBUlq25YTgworHWi2fdQvfN2VjYhHd%2FuUxab2%2BUwHM0FUh2mxUm74VT3FEJgDWGpQb8hnL4FA8AXuaTKCs%2B3RheFyHPHB8rq0%2B%2FTQzTQ7856nW3zesI%2BVrjVCY3m%2B6BaOafaytHn8eCv0FVNsOkuqvtnRyuxkWHMKDON53MvvDWpsHu3BNNTNFSwuVDq7YhogahNeHlP%2F5QOi7mRv%2BX4fnvlgigZHzvW%2BS1hsRyAjYYbiu07tk37%2BF3rjPgZw%3D%3D', swid='{D29A0BC7-76B3-4AF2-A91D-7F2ADC252CE4}')

# %%
result = league.power_rankings(13)
print(type(result))
print(result[0])
# Out:
# <class 'list'>
# ('69.50', Team(Flyreek Chills and Puk Nukem))

# %%
league.fetch_league()

# %%
box_scores = league.box_scores(12)
league.power_rankings(13)
# Out:
# [('63.80', Team(Mardz Maye-hem)),
#  ('59.15', Team(St. Antonio CardinalSpurs)),
#  ('57.95', Team(Puka and Rally)),
#  ('56.65', Team(Spano Da Champ)),
#  ('50.70', Team(The Curse of Jerry Jeudy)),
#  ('48.30', Team(Domestic Judkins)),
#  ('47.70', Team(The Gravy Chuggers)),
#  ('37.85', Team(LimitSpano)),
#  ('34.70', Team(Herberts perberts)),
#  ('30.80', Team(Bo Knows)),
#  ('27.75', Team(Zacher Football Team)),
#  ('24.95', Team(Mister Doyle's Naberhood ))]

# %%
league.fetch_league()
team = league.teams[1]
print(team.roster)
roster = team.roster
player = team.roster[0]
print(player.playerId)
print(player.name)
print(player.position)
# Out:
# [Player(Christian McCaffrey), Player(Jonathan Taylor), Player(Terry McLaurin), Player(Mike Evans), Player(Patrick Mahomes), Player(RJ Harvey), Player(Mark Andrews), Player(Emeka Egbuka), Player(Joe Mixon), Player(Brian Robinson Jr.), Player(Harold Fannin Jr.), Player(Romeo Doubs), Player(Will Reichard), Player(Jauan Jennings), Player(Steelers D/ST), Player(Raiders D/ST)]
# 3117251
# Christian McCaffrey
# RB

# %%
box_scores = league.box_scores(12)
print(box_scores)
box_scores[0].home_team
box_scores[0].home_score
# Out:
# [Box Score(Team(The Gravy Chuggers) at Team(Zacher Football Team)), Box Score(Team(Domestic Judkins) at Team(The Curse of Jerry Jeudy)), Box Score(Team(Puka and Rally) at Team(LimitSpano)), Box Score(Team(Bo Knows) at Team(Herberts perberts)), Box Score(Team(Mister Doyle's Naberhood ) at Team(Spano Da Champ)), Box Score(Team(Mardz Maye-hem) at Team(St. Antonio CardinalSpurs))]
# 115.75

# %%
box = league.box_scores(12)
print(box)
# Out:
# [Box Score(Team(The Gravy Chuggers) at Team(Zacher Football Team)), Box Score(Team(Domestic Judkins) at Team(The Curse of Jerry Jeudy)), Box Score(Team(Puka and Rally) at Team(LimitSpano)), Box Score(Team(Bo Knows) at Team(Herberts perberts)), Box Score(Team(Mister Doyle's Naberhood ) at Team(Spano Da Champ)), Box Score(Team(Mardz Maye-hem) at Team(St. Antonio CardinalSpurs))]
